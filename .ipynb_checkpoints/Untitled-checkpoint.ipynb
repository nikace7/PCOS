# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

# %%
pip install opencv-python

# %%
pip install opencv-python

# %%
pip install numpy

# %%
pip install matplotlib

# %%
pip install --ignore-installed --upgrade tensorflow

# %%
def preprocess_image(image_path):
    # Load the image
    image = cv2.imread(image_path)

    # Noise removal using Gaussian Blur
    image = cv2.GaussianBlur(image, (5, 5), 0)

    # Convert to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Resize to 64x64
    image_64 = cv2.resize(gray_image, (64, 64))

    # Resize to 128x128
    image_128 = cv2.resize(gray_image, (128, 128))

    return image_64, image_128

# %%
def preprocess_dataset(dataset_path):
    images_64 = []
    images_128 = []
    labels = []

    # Loop through each class folder in the dataset path
    for class_folder in os.listdir(dataset_path):
        class_path = os.path.join(dataset_path, class_folder)
        if os.path.isdir(class_path):
            for image_file in os.listdir(class_path):
                image_path = os.path.join(class_path, image_file)
                image_64, image_128 = preprocess_image(image_path)

                # Append images and their labels
                images_64.append(image_64)
                images_128.append(image_128)
                labels.append(class_folder)

    return np.array(images_64), np.array(images_128), np.array(labels)

# %%
train_path = '/content/drive/MyDrive/PCOS_Ultrasound_Dataset/train'
test_path = '/content/drive/MyDrive/PCOS_Ultrasound_Dataset/test'

# %%
import os
from PIL import Image, UnidentifiedImageError

# Directory to check
image_dirs = ['C:\\Users\\khatr\\OneDrive - Prime College\\Desktop\\ML\\data\\train', 'C:\\Users\\khatr\\OneDrive - Prime College\\Desktop\\ML\\data\\test']

# Loop through all files and attempt to open them
for image_dir in image_dirs:
    for root, dirs, files in os.walk(image_dir):
        for file in files:
            file_path = os.path.join(root, file)
            try:
                with Image.open(file_path) as img:
                    img.verify()  # Verify the image file
            except (UnidentifiedImageError, OSError, ValueError) as e:
                print(f"Corrupt or invalid image found and skipped: {file_path} - {e}")

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from PIL import Image, UnidentifiedImageError
import os

# Set up directories
train_dir = r'C:\Users\khatr\OneDrive - Prime College\Desktop\ML\data\train'
test_dir = r'C:\Users\khatr\OneDrive - Prime College\Desktop\ML\data\test'

# Image preprocessing and augmentation
target_size = (64, 64)
batch_size = 8
epochs = 100

# Ensure that TensorFlow uses the GPU
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    print("GPU is available and will be used for training.")
else:
    print("GPU not available, training will proceed on the CPU.")

# Custom function to safely load images and skip corrupt ones
def safe_load_img(path, color_mode='rgb', target_size=None, interpolation='nearest'):
    try:
        img = tf.keras.utils.load_img(path, color_mode=color_mode, target_size=target_size, interpolation=interpolation)
        img.verify()  # Verify that this is a valid image file
        return img
    except (UnidentifiedImageError, OSError, ValueError) as e:
        print(f"Skipping invalid image {path}: {e}")
        return None

# Custom data generator that skips corrupt images
class SafeImageDataGenerator(ImageDataGenerator):
    def _get_batches_of_transformed_samples(self, index_array):
        batch_x = []
        batch_y = []
        for i in index_array:
            img_path = self.filepaths[i]
            img = safe_load_img(img_path, color_mode=self.color_mode, target_size=self.target_size)
            if img is not None:
                img_array = tf.keras.utils.img_to_array(img)
                batch_x.append(img_array)
                batch_y.append(self.labels[i])
        return np.array(batch_x), np.array(batch_y)

train_datagen = SafeImageDataGenerator(
    rescale=1./255,  # Normalize pixel values
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = SafeImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=target_size,
    batch_size=batch_size,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=target_size,
    batch_size=batch_size,
    class_mode='binary'
)

# Define the CNN model
def build_cnn_model(input_shape):
    model = Sequential()

    # Input layer
    model.add(Input(shape=input_shape))

    # Convolutional Layer 1
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # Convolutional Layer 2
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # Convolutional Layer 3
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # Flatten the output
    model.add(Flatten())

    # Fully Connected Layer
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))  # Prevent overfitting
    model.add(Dense(1, activation='sigmoid'))  # Sigmoid for binary classification

    # Compile the model
    model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Build the model with input shape (64, 64, 3) for color images (3 channels)
input_shape = (64, 64, 3)
cnn_model = build_cnn_model(input_shape)

# Train the model
history = cnn_model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=test_generator,
    validation_steps=test_generator.samples // batch_size
)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from PIL import Image, UnidentifiedImageError
import os

# Set up directories
train_dir = r'C:\Users\khatr\OneDrive - Prime College\Desktop\ML\data\train'
test_dir = r'C:\Users\khatr\OneDrive - Prime College\Desktop\ML\data\test'

# Image preprocessing and augmentation
target_size = (128, 128)
batch_size = 8
epochs = 100

# Ensure that TensorFlow uses the GPU
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    print("GPU is available and will be used for training.")
else:
    print("GPU not available, training will proceed on the CPU.")

# Custom function to safely load images and skip corrupt ones
def safe_load_img(path, color_mode='rgb', target_size=None, interpolation='nearest'):
    try:
        img = tf.keras.utils.load_img(path, color_mode=color_mode, target_size=target_size, interpolation=interpolation)
        img.verify()  # Verify that this is a valid image file
        return img
    except (UnidentifiedImageError, OSError, ValueError) as e:
        print(f"Skipping invalid image {path}: {e}")
        return None

# Custom data generator that skips corrupt images
class SafeImageDataGenerator(ImageDataGenerator):
    def _get_batches_of_transformed_samples(self, index_array):
        batch_x = []
        batch_y = []
        for i in index_array:
            img_path = self.filepaths[i]
            img = safe_load_img(img_path, color_mode=self.color_mode, target_size=self.target_size)
            if img is not None:
                img_array = tf.keras.utils.img_to_array(img)
                batch_x.append(img_array)
                batch_y.append(self.labels[i])
        return np.array(batch_x), np.array(batch_y)

train_datagen = SafeImageDataGenerator(
    rescale=1./255,  # Normalize pixel values
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = SafeImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=target_size,
    batch_size=batch_size,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=target_size,
    batch_size=batch_size,
    class_mode='binary'
)

# Define the CNN model
def build_cnn_model(input_shape):
    model = Sequential()

    # Input layer
    model.add(Input(shape=input_shape))

    # Convolutional Layer 1
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # Convolutional Layer 2
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # Convolutional Layer 3
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # Flatten the output
    model.add(Flatten())

    # Fully Connected Layer
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))  # Prevent overfitting
    model.add(Dense(1, activation='sigmoid'))  # Sigmoid for binary classification

    # Compile the model
    model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Build the model with input shape (64, 64, 3) for color images (3 channels)
input_shape = (128, 128, 3)
cnn_model = build_cnn_model(input_shape)

# Define the checkpoint callback to save the best model
checkpoint = ModelCheckpoint(
    'best_model.keras',  # Path to save the model
    monitor='val_loss',  # Metric to monitor (e.g., 'val_loss', 'val_accuracy')
    save_best_only=True,  # Save only the model with the best performance
    mode='min',  # Mode should be 'min' for loss (for accuracy use 'max')
    verbose=1  # Verbosity mode
)

# Train the model with the checkpoint callback
history = cnn_model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=test_generator,
    validation_steps=test_generator.samples // batch_size,
    callbacks=[checkpoint]  # Include the checkpoint callback in the training
)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from PIL import Image, UnidentifiedImageError
import os

# Set up directories
train_dir = r'C:\Users\khatr\OneDrive - Prime College\Desktop\ML\data\train'
test_dir = r'C:\Users\khatr\OneDrive - Prime College\Desktop\ML\data\test'

# Image preprocessing and augmentation
target_size = (128, 128)
batch_size = 4
epochs = 100

# Ensure that TensorFlow uses the GPU
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    print("GPU is available and will be used for training.")
else:
    print("GPU not available, training will proceed on the CPU.")

# Custom function to safely load images and skip corrupt ones
def safe_load_img(path, color_mode='rgb', target_size=None, interpolation='nearest'):
    try:
        img = tf.keras.utils.load_img(path, color_mode=color_mode, target_size=target_size, interpolation=interpolation)
        img.verify()  # Verify that this is a valid image file
        return img
    except (UnidentifiedImageError, OSError, ValueError) as e:
        print(f"Skipping invalid image {path}: {e}")
        return None

# Custom data generator that skips corrupt images
class SafeImageDataGenerator(ImageDataGenerator):
    def _get_batches_of_transformed_samples(self, index_array):
        batch_x = []
        batch_y = []
        for i in index_array:
            img_path = self.filepaths[i]
            img = safe_load_img(img_path, color_mode=self.color_mode, target_size=self.target_size)
            if img is not None:
                img_array = tf.keras.utils.img_to_array(img)
                batch_x.append(img_array)
                batch_y.append(self.labels[i])
        return np.array(batch_x), np.array(batch_y)

train_datagen = SafeImageDataGenerator(
    rescale=1./255,  # Normalize pixel values
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = SafeImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=target_size,
    batch_size=batch_size,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=target_size,
    batch_size=batch_size,
    class_mode='binary'
)

# Define the CNN model with added BatchNormalization and increased complexity
def build_cnn_model(input_shape):
    model = Sequential()

    # Input layer
    model.add(Input(shape=input_shape))

    # Convolutional Layer 1
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # Convolutional Layer 2
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # Convolutional Layer 3
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # Flatten the output
    model.add(Flatten())

    # Fully Connected Layer
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))  # Prevent overfitting
    model.add(Dense(1, activation='sigmoid'))  # Sigmoid for binary classification

    # Compile the model
    model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Build the model with input shape (64, 64, 3) for color images (3 channels)
input_shape = (128, 128, 3)
cnn_model = build_cnn_model(input_shape)

# Define the checkpoint callback to save the best model
checkpoint = ModelCheckpoint(
    'best_model.keras',  # Path to save the model
    monitor='val_loss',  # Metric to monitor (e.g., 'val_loss', 'val_accuracy')
    save_best_only=True,  # Save only the model with the best performance
    mode='min',  # Mode should be 'min' for loss (for accuracy use 'max')
    verbose=1  # Verbosity mode
)

# Define a learning rate scheduler callback
def scheduler(epoch, lr):
    if epoch < 10:
        return float(lr)  # Ensure lr is a float
    else:
        return float(lr * tf.math.exp(-0.1))  # Ensure the result is a float

lr_scheduler = LearningRateScheduler(scheduler)

# Train the model with the checkpoint and learning rate scheduler callbacks
history = cnn_model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=test_generator,
    validation_steps=test_generator.samples // batch_size,
    callbacks=[checkpoint, lr_scheduler]  # Include the checkpoint and learning rate scheduler callbacks in the training
)
# Out:
# GPU not available, training will proceed on the CPU.
# Found 1730 images belonging to 2 classes.
# Found 193 images belonging to 2 classes.
# Epoch 1/100
# C:\Users\khatr\OneDrive - Prime College\Desktop\ML\PCOS\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 431/432 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9057 - loss: 1.1517
# Epoch 1: val_loss improved from inf to 0.10942, saving model to best_model.keras
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - accuracy: 0.9059 - loss: 1.1498 - val_accuracy: 0.9740 - val_loss: 0.1094 - learning_rate: 0.0010
# Epoch 2/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 43s 100ms/step - accuracy: 1.0000 - loss: 2.0796e-04
# Epoch 2: val_loss improved from 0.10942 to 0.00000, saving model to best_model.keras
# C:\Users\khatr\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - accuracy: 1.0000 - loss: 2.0796e-04 - val_accuracy: 1.0000 - val_loss: 1.0287e-18 - learning_rate: 0.0010
# Epoch 3/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9736 - loss: 0.3888
# Epoch 3: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.9736 - loss: 0.3889 - val_accuracy: 1.0000 - val_loss: 4.8378e-07 - learning_rate: 0.0010
# Epoch 4/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 32s 76ms/step - accuracy: 1.0000 - loss: 2.3540e-31
# Epoch 4: val_loss improved from 0.00000 to 0.00000, saving model to best_model.keras
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 1.0000 - loss: 2.3540e-31 - val_accuracy: 1.0000 - val_loss: 1.0441e-23 - learning_rate: 0.0010
# Epoch 5/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9839 - loss: 0.3391
# Epoch 5: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - accuracy: 0.9839 - loss: 0.3390 - val_accuracy: 0.9948 - val_loss: 0.0453 - learning_rate: 0.0010
# Epoch 6/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 19s 46ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 6: val_loss improved from 0.00000 to 0.00000, saving model to best_model.keras
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 7/100
# 430/432 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9942 - loss: 0.0715
# Epoch 7: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.9942 - loss: 0.0715 - val_accuracy: 1.0000 - val_loss: 7.9156e-10 - learning_rate: 0.0010
# Epoch 8/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 20s 48ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 8: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 48us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 9/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9971 - loss: 0.0307
# Epoch 9: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.9971 - loss: 0.0310 - val_accuracy: 0.9948 - val_loss: 0.0927 - learning_rate: 0.0010
# Epoch 10/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 13s 31ms/step - accuracy: 1.0000 - loss: 0.0063
# Epoch 10: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 40us/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 1.9650e-34 - learning_rate: 0.0010
# Epoch 11/100
# 431/432 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9906 - loss: 0.0687
# Epoch 11: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - accuracy: 0.9907 - loss: 0.0688 - val_accuracy: 1.0000 - val_loss: 1.2184e-04 - learning_rate: 9.0484e-04
# Epoch 12/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 20s 48ms/step - accuracy: 1.0000 - loss: 5.8593e-38
# Epoch 12: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 44us/step - accuracy: 1.0000 - loss: 5.8593e-38 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 8.1873e-04
# Epoch 13/100
# 431/432 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9948 - loss: 0.1198
# Epoch 13: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.9948 - loss: 0.1199 - val_accuracy: 0.9375 - val_loss: 1.2621 - learning_rate: 7.4082e-04
# Epoch 14/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 16s 38ms/step - accuracy: 1.0000 - loss: 5.9260e-14
# Epoch 14: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 41us/step - accuracy: 1.0000 - loss: 5.9260e-14 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 6.7032e-04
# Epoch 15/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9871 - loss: 0.2501
# Epoch 15: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.9871 - loss: 0.2498 - val_accuracy: 1.0000 - val_loss: 3.4551e-14 - learning_rate: 6.0653e-04
# Epoch 16/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 21s 51ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 16: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 46us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 5.4881e-04
# Epoch 17/100
# 431/432 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9923 - loss: 0.1017
# Epoch 17: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.9923 - loss: 0.1016 - val_accuracy: 1.0000 - val_loss: 4.0127e-12 - learning_rate: 4.9659e-04
# Epoch 18/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 18s 44ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 18: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 140us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 4.4933e-04
# Epoch 19/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9960 - loss: 0.0913
# Epoch 19: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 0.9960 - loss: 0.0913 - val_accuracy: 1.0000 - val_loss: 1.0242e-21 - learning_rate: 4.0657e-04
# Epoch 20/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 30s 70ms/step - accuracy: 1.0000 - loss: 2.6996e-35
# Epoch 20: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 46us/step - accuracy: 1.0000 - loss: 2.6996e-35 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 3.6788e-04
# Epoch 21/100
# 431/432 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 6.1031e-04
# Epoch 21: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 1.0000 - loss: 6.0939e-04 - val_accuracy: 1.0000 - val_loss: 2.7994e-25 - learning_rate: 3.3287e-04
# Epoch 22/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 1.0000 - loss: 9.4556e-30
# Epoch 22: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 51us/step - accuracy: 1.0000 - loss: 9.4556e-30 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 3.0119e-04
# Epoch 23/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9983 - loss: 0.0716
# Epoch 23: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.9983 - loss: 0.0716 - val_accuracy: 1.0000 - val_loss: 2.3081e-16 - learning_rate: 2.7253e-04
# Epoch 24/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 17s 41ms/step - accuracy: 0.7500 - loss: 0.1822
# Epoch 24: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 42us/step - accuracy: 0.7500 - loss: 0.1822 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 2.4660e-04
# Epoch 25/100
# 430/432 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9998 - loss: 0.0034
# Epoch 25: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.9998 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 2.9305e-13 - learning_rate: 2.2313e-04
# Epoch 26/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 15s 35ms/step - accuracy: 1.0000 - loss: 2.0961e-32
# Epoch 26: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 47us/step - accuracy: 1.0000 - loss: 2.0961e-32 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 2.0190e-04
# Epoch 27/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9991 - loss: 0.0352
# Epoch 27: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.9991 - loss: 0.0352 - val_accuracy: 1.0000 - val_loss: 2.0210e-23 - learning_rate: 1.8268e-04
# Epoch 28/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 28: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 48us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 1.6530e-04
# Epoch 29/100
# 431/432 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9994 - loss: 0.0083
# Epoch 29: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.9994 - loss: 0.0083 - val_accuracy: 1.0000 - val_loss: 3.4390e-23 - learning_rate: 1.4957e-04
# Epoch 30/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 25s 59ms/step - accuracy: 1.0000 - loss: 2.8501e-30
# Epoch 30: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 163us/step - accuracy: 1.0000 - loss: 2.8501e-30 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 1.3534e-04
# Epoch 31/100
# 431/432 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9975 - loss: 0.0091
# Epoch 31: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 15s 33ms/step - accuracy: 0.9975 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 5.2540e-20 - learning_rate: 1.2246e-04
# Epoch 32/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 17s 40ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 32: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 44us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 4.3990e-38 - learning_rate: 1.1080e-04
# Epoch 33/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9987 - loss: 0.0285
# Epoch 33: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.9987 - loss: 0.0285 - val_accuracy: 1.0000 - val_loss: 1.3427e-23 - learning_rate: 1.0026e-04
# Epoch 34/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 15s 35ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 34: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 41us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 9.0718e-05
# Epoch 35/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9997 - loss: 0.0018
# Epoch 35: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.9997 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 6.3668e-23 - learning_rate: 8.2085e-05
# Epoch 36/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 28s 66ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 36: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 67us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 7.4274e-05
# Epoch 37/100
# 431/432 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 7.3152e-06
# Epoch 37: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 1.0000 - loss: 7.4104e-06 - val_accuracy: 1.0000 - val_loss: 6.2465e-22 - learning_rate: 6.7206e-05
# Epoch 38/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 25s 58ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 38: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 44us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 6.0810e-05
# Epoch 39/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 9.6609e-08
# Epoch 39: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - accuracy: 1.0000 - loss: 9.6452e-08 - val_accuracy: 1.0000 - val_loss: 7.7050e-23 - learning_rate: 5.5023e-05
# Epoch 40/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 18s 43ms/step - accuracy: 1.0000 - loss: 9.5173e-30
# Epoch 40: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 45us/step - accuracy: 1.0000 - loss: 9.5173e-30 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 4.9787e-05
# Epoch 41/100
# 431/432 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9994 - loss: 0.0013
# Epoch 41: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.9994 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 9.2955e-23 - learning_rate: 4.5049e-05
# Epoch 42/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 18s 43ms/step - accuracy: 1.0000 - loss: 3.5946e-36
# Epoch 42: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 136us/step - accuracy: 1.0000 - loss: 3.5946e-36 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 4.0762e-05
# Epoch 43/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 2.8696e-05
# Epoch 43: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 14s 32ms/step - accuracy: 1.0000 - loss: 3.2687e-05 - val_accuracy: 1.0000 - val_loss: 2.8031e-22 - learning_rate: 3.6883e-05
# Epoch 44/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 30s 71ms/step - accuracy: 1.0000 - loss: 4.5137e-25
# Epoch 44: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 51us/step - accuracy: 1.0000 - loss: 4.5137e-25 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 3.3373e-05
# Epoch 45/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9997 - loss: 0.0025
# Epoch 45: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 14s 32ms/step - accuracy: 0.9997 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 1.1836e-23 - learning_rate: 3.0197e-05
# Epoch 46/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 29s 69ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 46: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 61us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 2.7324e-05
# Epoch 47/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9994 - loss: 0.0027
# Epoch 47: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - accuracy: 0.9994 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 1.3651e-21 - learning_rate: 2.4724e-05
# Epoch 48/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 20s 47ms/step - accuracy: 1.0000 - loss: 1.4800e-29
# Epoch 48: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 46us/step - accuracy: 1.0000 - loss: 1.4800e-29 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 2.2371e-05
# Epoch 49/100
# 431/432 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 3.5642e-06
# Epoch 49: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 1.0000 - loss: 4.4865e-06 - val_accuracy: 1.0000 - val_loss: 1.2867e-21 - learning_rate: 2.0242e-05
# Epoch 50/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 50: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 43us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 1.3933e-32 - learning_rate: 1.8316e-05
# Epoch 51/100
# 431/432 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9997 - loss: 6.2404e-04
# Epoch 51: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - accuracy: 0.9997 - loss: 6.2750e-04 - val_accuracy: 1.0000 - val_loss: 6.2003e-22 - learning_rate: 1.6573e-05
# Epoch 52/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 16s 38ms/step - accuracy: 1.0000 - loss: 4.7476e-28
# Epoch 52: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 64us/step - accuracy: 1.0000 - loss: 4.7476e-28 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 1.4996e-05
# Epoch 53/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9999 - loss: 8.8236e-04
# Epoch 53: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - accuracy: 0.9999 - loss: 8.9533e-04 - val_accuracy: 1.0000 - val_loss: 5.6268e-21 - learning_rate: 1.3569e-05
# Epoch 54/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 24s 57ms/step - accuracy: 1.0000 - loss: 1.0288e-30
# Epoch 54: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 129us/step - accuracy: 1.0000 - loss: 1.0288e-30 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 1.2277e-05
# Epoch 55/100
# 431/432 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9985 - loss: 0.0027
# Epoch 55: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 14s 32ms/step - accuracy: 0.9985 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 3.5015e-21 - learning_rate: 1.1109e-05
# Epoch 56/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 16s 39ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 56: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 54us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 1.0052e-05
# Epoch 57/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.3969e-04
# Epoch 57: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 1.0000 - loss: 1.4005e-04 - val_accuracy: 1.0000 - val_loss: 2.8324e-21 - learning_rate: 9.0953e-06
# Epoch 58/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 26s 62ms/step - accuracy: 1.0000 - loss: 9.8918e-31
# Epoch 58: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 63us/step - accuracy: 1.0000 - loss: 9.8918e-31 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 8.2298e-06
# Epoch 59/100
# 430/432 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9996 - loss: 0.0025
# Epoch 59: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 14s 30ms/step - accuracy: 0.9996 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 3.1923e-21 - learning_rate: 7.4466e-06
# Epoch 60/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 17s 40ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 60: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 46us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 6.7379e-06
# Epoch 61/100
# 430/432 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 1.3377e-08
# Epoch 61: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 1.0000 - loss: 1.3826e-08 - val_accuracy: 1.0000 - val_loss: 5.0760e-20 - learning_rate: 6.0967e-06
# Epoch 62/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 18s 44ms/step - accuracy: 1.0000 - loss: 4.6208e-30
# Epoch 62: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 43us/step - accuracy: 1.0000 - loss: 4.6208e-30 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 5.5166e-06
# Epoch 63/100
# 430/432 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9998 - loss: 0.0013
# Epoch 63: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.9998 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 2.3043e-21 - learning_rate: 4.9916e-06
# Epoch 64/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 16s 39ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 64: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 47us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 4.5166e-06
# Epoch 65/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 6.2251e-05
# Epoch 65: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 1.0000 - loss: 7.4459e-05 - val_accuracy: 1.0000 - val_loss: 2.2273e-21 - learning_rate: 4.0868e-06
# Epoch 66/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 17s 39ms/step - accuracy: 1.0000 - loss: 1.8894e-15
# Epoch 66: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 135us/step - accuracy: 1.0000 - loss: 1.8894e-15 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 3.6979e-06
# Epoch 67/100
# 431/432 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 6.7192e-08
# Epoch 67: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 1.0000 - loss: 6.7710e-08 - val_accuracy: 1.0000 - val_loss: 5.1366e-23 - learning_rate: 3.3460e-06
# Epoch 68/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 68: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 43us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 3.0276e-06
# Epoch 69/100
# 431/432 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9999 - loss: 0.0012
# Epoch 69: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 3.0566e-22 - learning_rate: 2.7394e-06
# Epoch 70/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 1.0000 - loss: 7.3090e-34
# Epoch 70: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 44us/step - accuracy: 1.0000 - loss: 7.3090e-34 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 2.4788e-06
# Epoch 71/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 1.2650e-04
# Epoch 71: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 1.0000 - loss: 1.2631e-04 - val_accuracy: 1.0000 - val_loss: 2.4380e-21 - learning_rate: 2.2429e-06
# Epoch 72/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 17s 41ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 72: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 42us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 2.0294e-06
# Epoch 73/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9996 - loss: 4.8084e-04
# Epoch 73: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.9996 - loss: 4.8114e-04 - val_accuracy: 1.0000 - val_loss: 9.7814e-22 - learning_rate: 1.8363e-06
# Epoch 74/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 18s 42ms/step - accuracy: 1.0000 - loss: 2.1933e-34
# Epoch 74: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 44us/step - accuracy: 1.0000 - loss: 2.1933e-34 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 1.6616e-06
# Epoch 75/100
# 430/432 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9992 - loss: 0.0112
# Epoch 75: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.9992 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 1.1730e-21 - learning_rate: 1.5034e-06
# Epoch 76/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 1.0000 - loss: 5.1652e-17
# Epoch 76: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 40us/step - accuracy: 1.0000 - loss: 5.1652e-17 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 1.3604e-06
# Epoch 77/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 7.2973e-04
# Epoch 77: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 1.0000 - loss: 7.2886e-04 - val_accuracy: 1.0000 - val_loss: 2.1158e-21 - learning_rate: 1.2309e-06
# Epoch 78/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 1.0000 - loss: 2.2836e-32
# Epoch 78: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 130us/step - accuracy: 1.0000 - loss: 2.2836e-32 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 1.1138e-06
# Epoch 79/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9973 - loss: 0.0499
# Epoch 79: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.9973 - loss: 0.0498 - val_accuracy: 1.0000 - val_loss: 1.5649e-21 - learning_rate: 1.0078e-06
# Epoch 80/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 80: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 42us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 9.1188e-07
# Epoch 81/100
# 431/432 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9995 - loss: 0.0022
# Epoch 81: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.9995 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 8.9849e-22 - learning_rate: 8.2511e-07
# Epoch 82/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 12s 30ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 82: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 50us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 7.4659e-07
# Epoch 83/100
# 430/432 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9972 - loss: 0.0149
# Epoch 83: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.9972 - loss: 0.0151 - val_accuracy: 1.0000 - val_loss: 5.2093e-22 - learning_rate: 6.7554e-07
# Epoch 84/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 1.0000 - loss: 5.4925e-37
# Epoch 84: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 38us/step - accuracy: 1.0000 - loss: 5.4925e-37 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 6.1125e-07
# Epoch 85/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9993 - loss: 0.0099
# Epoch 85: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.9993 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 5.4171e-22 - learning_rate: 5.5308e-07
# Epoch 86/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 1.0000 - loss: 4.0045e-35
# Epoch 86: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 38us/step - accuracy: 1.0000 - loss: 4.0045e-35 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 5.0045e-07
# Epoch 87/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 1.0769e-05
# Epoch 87: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 1.0000 - loss: 1.0756e-05 - val_accuracy: 1.0000 - val_loss: 1.6886e-22 - learning_rate: 4.5283e-07
# Epoch 88/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 15s 36ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 88: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 39us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 4.0974e-07
# Epoch 89/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9999 - loss: 1.4287e-04
# Epoch 89: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.9999 - loss: 1.4442e-04 - val_accuracy: 1.0000 - val_loss: 1.7279e-21 - learning_rate: 3.7074e-07
# Epoch 90/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 90: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 124us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 3.3546e-07
# Epoch 91/100
# 430/432 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 2.0289e-08
# Epoch 91: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 1.0000 - loss: 2.0267e-08 - val_accuracy: 1.0000 - val_loss: 2.3456e-21 - learning_rate: 3.0354e-07
# Epoch 92/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 92: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 34us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 2.7465e-07
# Epoch 93/100
# 431/432 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9998 - loss: 5.8763e-04
# Epoch 93: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.9998 - loss: 5.9320e-04 - val_accuracy: 1.0000 - val_loss: 1.2858e-21 - learning_rate: 2.4852e-07
# Epoch 94/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 1.0000 - loss: 4.2714e-29
# Epoch 94: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 41us/step - accuracy: 1.0000 - loss: 4.2714e-29 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 2.2487e-07
# Epoch 95/100
# 430/432 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9998 - loss: 1.7312e-04
# Epoch 95: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.9998 - loss: 1.7614e-04 - val_accuracy: 1.0000 - val_loss: 4.4587e-22 - learning_rate: 2.0347e-07
# Epoch 96/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 96: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 39us/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 1.8411e-07
# Epoch 97/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9999 - loss: 1.1222e-04
# Epoch 97: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.9999 - loss: 1.1304e-04 - val_accuracy: 1.0000 - val_loss: 1.0913e-21 - learning_rate: 1.6659e-07
# Epoch 98/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 1.0000 - loss: 4.8307e-38
# Epoch 98: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 35us/step - accuracy: 1.0000 - loss: 4.8307e-38 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 1.5073e-07
# Epoch 99/100
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9986 - loss: 0.0016
# Epoch 99: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.9986 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 7.3837e-22 - learning_rate: 1.3639e-07
# Epoch 100/100
#   1/432 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 1.0000 - loss: 4.6936e-29
# Epoch 100: val_loss did not improve from 0.00000
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 38us/step - accuracy: 1.0000 - loss: 4.6936e-29 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 1.2341e-07

# %%
import tensorflow as tf
import numpy as np

# Load the best saved model for inference
best_model = tf.keras.models.load_model('best_model.keras')

# Example inference on a single image
def predict_image(img_path, model):
    # Load and preprocess the image
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=(128, 128))  # Adjusted to match the model input size
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array /= 255.0  # Normalize the image

    # Make a prediction
    prediction = model.predict(img_array)
    
    # Decode the prediction (for binary classification)
    predicted_class = (prediction > 0.5).astype("int32")  # Adjust based on binary classification threshold
    return predicted_class, prediction

# Example usage for inference
img_path = 'aa.png'  # Provide the path to an image for prediction
predicted_class, prediction = predict_image(img_path, best_model)
print(f'Predicted class: {predicted_class}')
print(f'Prediction confidence: {prediction}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 923ms/step
# Predicted class: [[1]]
# Prediction confidence: [[1.]]
